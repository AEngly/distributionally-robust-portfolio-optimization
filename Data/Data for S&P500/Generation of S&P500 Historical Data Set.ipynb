# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Load constituents and there tickers.

# %%
TICKERS = [
    "AMZN", # Amazon (CONSUMER DISCRETIONARY)
    "V", # Visa (FINANCIALS)
    "BRK-B", # Birkshire Hathaway (FINANCIALS)
    "BMY", # Bristol-Meyers Squibb Company (HEALTH CARE)
    "QCOM", # Qualcomm (INFORMATION TECHNOLOGY)
    "CSCO", # Cisco (INFORMATION TECHNOLOGY)
    "KO", # Coca Cola (CONSUMER STABLES)
    "NEE" #NextEra Energi Inc. (ENERGY)
]

# %%
constituents = pd.read_csv(r'S&P 500 Historical Components & Changes.csv')

# %%
TICKERS = constituents['tickers'].iloc[-1].split(",")

# %% [markdown]
# Fetch the data from Yahoo Finance.

# %%
START = "2016-01-01"
END = "2022-01-01"

INTERVAL = "1mo"
stock_data = yf.download(
    tickers = TICKERS[:10],
    start = START,
    end = END,
    interval = INTERVAL
).dropna()['Adj Close']
# Out:
# [*********************100%***********************]  10 of 10 completed

# %%
stock_data
# Out:
#                    JPM        JWN          K        KEY        KEYS  \
# Date
# 2016-01-01   47.817402  39.532581  56.503155   8.316380   23.400000
# 2016-02-01   45.549225  41.320011  56.949383   7.861809   26.090000
# 2016-03-01   47.911633  46.062302  59.291676   8.285079   27.740000
# 2016-04-01   51.131630  41.457832  59.493042   9.223157   26.080000
# 2016-05-01   53.197308  30.795387  57.603153   9.620898   30.629999
# ...                ...        ...        ...        ...         ...
# 2021-08-01  150.770248  26.698181  58.325893  18.253481  179.380005
# 2021-09-01  154.295624  24.682524  59.593674  19.594801  164.289993
# 2021-10-01  160.139801  26.810163  57.151005  21.090239  180.020004
# 2021-11-01  150.616730  19.755348  57.039127  20.337990  194.479996
# 2021-12-01  150.161530  21.108458  60.610233  21.143396  206.509995
#
#                   KHC        KIM        KLAC         KMB        KMI
# Date
# 2016-01-01  56.550674  18.657694   57.226860   99.540329  11.175499
# ...
