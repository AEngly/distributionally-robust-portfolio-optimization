# %% [markdown]
# <center> <h1> Mean-Variance Optimization <h1/> <center/>

# %% [markdown]
# This notebook follows the tutorial presented by MOSEK here: https://www.mosek.com/resources/portfolio-optimization/

# %%
import sys
import os
import re
import glob
import datetime as dt

import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

from mosek.fusion import *

from notebook.services.config import ConfigManager

from portfolio_tools import data_download, DataReader
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [3], in <module>
#      14 from mosek.fusion import *
#      16 from notebook.services.config import ConfigManager
# ---> 18 from portfolio_tools import data_download, DataReader
#
# ModuleNotFoundError: No module named 'portfolio_tools'
